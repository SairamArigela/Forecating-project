# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
stock=pd.read_csv("C:\\Users\\Siva\\Desktop\\ExcelR\\Project\\AAPL.csv")
stock
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 1     2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2     2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 3     2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 4     2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...          ...         ...         ...         ...         ...         ...
# 2006  2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007  2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008  2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009  2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010  2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#         Volume
# 0     75555200
# 1     65005500
# 2     67817400
# 3     79573200
# 4     98506100
# ...        ...
# 2006  24643000
# 2007  12119700
# 2008  23280300
# 2009  36566500
# 2010  36028600
#
# [2011 rows x 7 columns]

# %%
import sklearn.metrics  
def RMSE(pred,org):
    value=np.sqrt(sklearn.metrics.mean_squared_error(org, pred)  )
    return value
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 1     2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2     2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 3     2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 4     2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...          ...         ...         ...         ...         ...         ...
# 1496  2017-12-12  172.149994  172.389999  171.460007  171.699997  165.514481
# 1497  2017-12-13  172.500000  173.539993  172.000000  172.270004  166.063950
# 1498  2017-12-14  172.399994  173.130005  171.649994  172.220001  166.015747
# 1499  2017-12-15  173.630005  174.169998  172.460007  173.970001  167.702698
# 1500  2017-12-18  174.880005  177.199997  174.860001  176.419998  170.064453
#
#         Volume
# 0     75555200
# 1     65005500
# 2     67817400
# 3     79573200
# 4     98506100
# ...        ...
# 1496  19409200
# 1497  23818400
# 1498  20476500
# 1499  40169300
# 1500  29421100
#
# [1501 rows x 7 columns]

# %%
train=stock.iloc[:1501,:]
test=stock.iloc[1501:,:]
train
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 1     2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2     2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 3     2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 4     2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...          ...         ...         ...         ...         ...         ...
# 1496  2017-12-12  172.149994  172.389999  171.460007  171.699997  165.514481
# 1497  2017-12-13  172.500000  173.539993  172.000000  172.270004  166.063950
# 1498  2017-12-14  172.399994  173.130005  171.649994  172.220001  166.015747
# 1499  2017-12-15  173.630005  174.169998  172.460007  173.970001  167.702698
# 1500  2017-12-18  174.880005  177.199997  174.860001  176.419998  170.064453
#
#         Volume
# 0     75555200
# 1     65005500
# 2     67817400
# 3     79573200
# 4     98506100
# ...        ...
# 1496  19409200
# 1497  23818400
# 1498  20476500
# 1499  40169300
# 1500  29421100
#
# [1501 rows x 7 columns]

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
sarima110 = SARIMAX(train['Close'], 
                 order=(1,1,1),
                seasonal_order=(1,1,1,126))

# %%
model110=sarima110.fit(disp=False,low_memory=True)

print(model110.summary())
print(model110.plot_diagnostics())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Close   No. Observations:                 1501
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 126)   Log Likelihood               -2696.578
# Date:                             Wed, 05 Apr 2023   AIC                           5403.156
# Time:                                     16:34:16   BIC                           5429.283
# Sample:                                          0   HQIC                          5412.932
#                                             - 1501
# Covariance Type:                            approx
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3785      0.484     -0.782      0.434      -1.327       0.570
# ma.L1          0.4035      0.478      0.844      0.399      -0.533       1.340
# ar.S.L126      0.0345      0.038      0.899      0.369      -0.041       0.110
# ma.S.L126     -0.8943      0.058    -15.490      0.000      -1.007      -0.781
# sigma2         2.5908      0.131     19.828      0.000       2.335       2.847
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):               638.64
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.17   Skew:                            -0.21
# Prob(H) (two-sided):                  0.10   Kurtosis:                         6.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# Figure(640x480)

# %%
train_pred110=model110.predict(start=train.Close.index[0], end=train.Close.index[-1])
test_pred110=model110.predict(start=test.Close.index[0], end=test.Close.index[-1])
print('RMSE:' ,RMSE(test_pred110,test.Close))
# Out:
# RMSE: 50.889010670338926

# %%
plt.figure(figsize=(20,8))
plt.plot(stock.Close, color='yellow',label="Actual")
plt.plot(train_pred110, color='green',label="Train Predicted")
plt.plot(test_pred110, color='blue', label="Test Predicted",)
plt.title('apple stock close value prediction by Sarima', fontsize=20)
plt.ylabel('Close', fontsize=16)
plt.legend()
plt.show()
